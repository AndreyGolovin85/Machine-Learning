# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreyGolovin85/Andrey/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3D-реализация алгоритма K-means на примере датасета ирисов Фишера.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn import datasets
np.random.seed(5)

# %%
# Загружаем датасет ирисов Фишера в переменную iris
iris = datasets.load_iris()
X = iris.data
y = iris.target
# Передаем параметры алгоритма в переменную k_means
k_means = [('k_means_iris_3', KMeans(n_clusters=3))]

# %%
# Для 3D-визуализации результатов работы алгоритма необходимо
# указать заголовок фигуры и параметры метода Axes3D.
fignum = 1
titles = ['3 clusters']

for name, est in k_means:
  fig = plt.figure(fignum, figsize=(4, 3))
  ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
  est.fit(X)
  labels = est.labels_
  # Передаем цвета точкам в кластерах.
  ax.scatter(x[:,3], x[:,0], x[:,2], c=labels.astype(np.float), edgecolor='k')
  # Добавляем подписи к осям x, y, z
  ax.w_xaxis.set_ticklabels([])
  ax.w_yaxis.set_ticklabels([])
  ax.w_zaxis.set_ticklabels([])
  ax.set_xlabel('Ширина лепестка')
  ax.set_ylabel('Длина чашелистника')
  ax.set_zlabel('Длина лепестка')

  ax.set_title(titles[fignum-1])
  ax.dist = 12
  fignum=fignum+1
